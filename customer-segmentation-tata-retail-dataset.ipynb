# %%
import pandas as pd

# Replace with your file path where the CSV is located
file_path = '/kaggle/input/tata-online-retail-dataset/Online Retail Data Set.csv'

# Read the CSV file into a pandas dataframe with specified encoding
retail_data = pd.read_csv(file_path, encoding='latin1')

# Display the first few rows of the dataframe
print(retail_data.head(20))
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
retail_data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
retail_data.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
retail_data.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
retail_data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.preprocessing import StandardScaler

# %%
retail_data.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
retail = retail_data

# %%
retail.shape
# Out:
# (541909, 8)

# %%
# Identify missing values
print("Missing Values:\n", retail.isnull())

# Drop rows with any missing values
retail_dropna = retail.dropna()
print("\nDataFrame after dropping rows with missing values:\n", retail_dropna)
# Out:
# Missing Values:
#          InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
retail = retail_dropna

# %%
retail.shape
# Out:
# (406829, 8)

# %%
retail.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
retail['CustomerID'] = retail['CustomerID'].astype(str)
# Out:
# /tmp/ipykernel_34/4138171746.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail['CustomerID'] = retail['CustomerID'].astype(str)

# %%
retail['CustomerID']
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: CustomerID, Length: 406829, dtype: object

# %%
retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  object
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  object
#  7   Country      406829 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 27.9+ MB

# %%
retail.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Calculate 'Amount' for each transaction
retail['Amount'] = retail['Quantity'] * retail['UnitPrice']

# Calculate Monetary (total spending per customer)
monetary = retail.groupby('CustomerID')['Amount'].sum().reset_index()
monetary.columns = ['CustomerID', 'Monetary']

# Display the Monetary DataFrame
print(monetary)
# Out:
# /tmp/ipykernel_34/2772368392.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail['Amount'] = retail['Quantity'] * retail['UnitPrice']
#      CustomerID  Monetary
# 0       12346.0      0.00
# 1       12347.0   4310.00
# 2       12348.0   1797.24
# 3       12349.0   1757.55
# 4       12350.0    334.40
# ...         ...       ...
# 4367    18280.0    180.60
# 4368    18281.0     80.82
# 4369    18282.0    176.60
# 4370    18283.0   2094.88
# 4371    18287.0   1837.28
#
# [4372 rows x 2 columns]

# %%
monetary.head(20)
# Out:
#    CustomerID  Monetary
# 0     12346.0      0.00
# 1     12347.0   4310.00
# 2     12348.0   1797.24
# 3     12349.0   1757.55
# 4     12350.0    334.40
# 5     12352.0   1545.41
# 6     12353.0     89.00
# 7     12354.0   1079.40
# 8     12355.0    459.40
# 9     12356.0   2811.43
# 10    12357.0   6207.67
# 11    12358.0   1168.06
# 12    12359.0   6245.53
# 13    12360.0   2662.06
# 14    12361.0    189.90
# 15    12362.0   5154.58
# 16    12363.0    552.00
# 17    12364.0   1313.10
# 18    12365.0    320.69
# 19    12367.0    168.90

# %%
monetary.shape
# Out:
# (4372, 2)

# %%
monetary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4372 entries, 0 to 4371
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  4372 non-null   object
#  1   Monetary    4372 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 68.4+ KB

# %%
retail.head(20)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
# Calculate Frequency (number of transactions per customer)
frequency = retail.groupby('CustomerID')['InvoiceNo'].count().reset_index()
frequency.columns = ['CustomerID', 'Frequency']

# Display the Frequency DataFrame
print(frequency)
# Out:
#      CustomerID  Frequency
# 0       12346.0          2
# 1       12347.0        182
# 2       12348.0         31
# 3       12349.0         73
# 4       12350.0         17
# ...         ...        ...
# 4367    18280.0         10
# 4368    18281.0          7
# 4369    18282.0         13
# 4370    18283.0        756
# 4371    18287.0         70
#
# [4372 rows x 2 columns]

# %%
frequency.head(20)
# Out:
#    CustomerID  Frequency
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17
# 5     12352.0         95
# 6     12353.0          4
# 7     12354.0         58
# 8     12355.0         13
# 9     12356.0         59
# 10    12357.0        131
# 11    12358.0         19
# 12    12359.0        254
# 13    12360.0        129
# 14    12361.0         10
# 15    12362.0        274
# 16    12363.0         23
# 17    12364.0         85
# 18    12365.0         23
# 19    12367.0         11

# %%
# Merge the two DataFrames on 'CustomerID'
rfm = pd.merge(monetary, frequency, on='CustomerID',how='inner')

rfm.head(20)
# Out:
#    CustomerID  Monetary  Frequency
# 0     12346.0      0.00          2
# 1     12347.0   4310.00        182
# 2     12348.0   1797.24         31
# 3     12349.0   1757.55         73
# 4     12350.0    334.40         17
# 5     12352.0   1545.41         95
# 6     12353.0     89.00          4
# 7     12354.0   1079.40         58
# 8     12355.0    459.40         13
# 9     12356.0   2811.43         59
# 10    12357.0   6207.67        131
# 11    12358.0   1168.06         19
# 12    12359.0   6245.53        254
# 13    12360.0   2662.06        129
# 14    12361.0    189.90         10
# 15    12362.0   5154.58        274
# 16    12363.0    552.00         23
# 17    12364.0   1313.10         85
# 18    12365.0    320.69         23
# 19    12367.0    168.90         11

# %%
# Convert 'InvoiceDate' to datetime format with specific format
retail['InvoiceDate'] = pd.to_datetime(retail['InvoiceDate'], format='%d-%m-%Y %H:%M')
# Out:
# /tmp/ipykernel_34/3097089797.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail['InvoiceDate'] = pd.to_datetime(retail['InvoiceDate'], format='%d-%m-%Y %H:%M')

# %%
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  Amount
# ...

# %%
recent_date = max(retail['InvoiceDate'])
recent_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
retail['Difference'] = (recent_date - retail['InvoiceDate']).dt.days
# Out:
# /tmp/ipykernel_34/106869165.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   retail['Difference'] = (recent_date - retail['InvoiceDate']).dt.days

# %%
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  Amount  \
# ...

# %%
recency = retail.groupby('CustomerID')['Difference'].min()
recency = recency.reset_index()
recency.head(20)
# Out:
#    CustomerID  Difference
# 0     12346.0         325
# 1     12347.0           1
# 2     12348.0          74
# 3     12349.0          18
# 4     12350.0         309
# 5     12352.0          35
# 6     12353.0         203
# 7     12354.0         231
# 8     12355.0         213
# 9     12356.0          22
# 10    12357.0          32
# 11    12358.0           1
# 12    12359.0           7
# 13    12360.0          51
# 14    12361.0         286
# 15    12362.0           2
# 16    12363.0         109
# 17    12364.0           7
# 18    12365.0         290
# 19    12367.0           3

# %%
retail.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Amount', 'Difference'],
#       dtype='object')

# %%
final_rfm = pd.merge(rfm,recency,on='CustomerID',how='inner')
final_rfm.columns = ['CustomerID','Amount','Frequency','Recency']
final_rfm.head(20)
# Out:
#    CustomerID   Amount  Frequency  Recency
# 0     12346.0     0.00          2      325
# 1     12347.0  4310.00        182        1
# 2     12348.0  1797.24         31       74
# 3     12349.0  1757.55         73       18
# 4     12350.0   334.40         17      309
# 5     12352.0  1545.41         95       35
# 6     12353.0    89.00          4      203
# 7     12354.0  1079.40         58      231
# 8     12355.0   459.40         13      213
# 9     12356.0  2811.43         59       22
# 10    12357.0  6207.67        131       32
# 11    12358.0  1168.06         19        1
# 12    12359.0  6245.53        254        7
# 13    12360.0  2662.06        129       51
# 14    12361.0   189.90         10      286
# 15    12362.0  5154.58        274        2
# 16    12363.0   552.00         23      109
# 17    12364.0  1313.10         85        7
# 18    12365.0   320.69         23      290
# 19    12367.0   168.90         11        3

# %%
attributes = ['Amount','Frequency','Recency']
# Set the figure size
plt.rcParams['figure.figsize'] = [10, 8]

# Create the box plot
sns.boxplot(data=final_rfm[attributes], orient="v", palette="Set2", saturation=1, width=0.7)

# Set the title and labels with styling
plt.title("Outliers Variable Distribution", fontsize=14, fontweight='bold')
plt.ylabel("Range", fontweight="bold")
plt.xlabel("Attributes", fontweight="bold")

# Display the plot
plt.show()

# %%
# Function to remove statistical outliers based on IQR
def remove_outliers(final_rfm, column):
    Q1 = final_rfm[column].quantile(0.05)
    Q3 = final_rfm[column].quantile(0.95)
    IQR = Q3 - Q1
    return final_rfm[(final_rfm[column] >= Q1 - 1.5 * IQR) & (final_rfm[column] <= Q3 + 1.5 * IQR)]

# Remove outliers for Amount, Recency, and Frequency
rfm = remove_outliers(final_rfm, 'Amount')
rfm = remove_outliers(final_rfm, 'Recency')
rfm = remove_outliers(final_rfm, 'Frequency')

# Display the updated DataFrame
rfm
# Out:
#      CustomerID   Amount  Frequency  Recency
# 0       12346.0     0.00          2      325
# 1       12347.0  4310.00        182        1
# 2       12348.0  1797.24         31       74
# 3       12349.0  1757.55         73       18
# 4       12350.0   334.40         17      309
# ...         ...      ...        ...      ...
# 4367    18280.0   180.60         10      277
# 4368    18281.0    80.82          7      180
# 4369    18282.0   176.60         13        7
# 4370    18283.0  2094.88        756        3
# 4371    18287.0  1837.28         70       42
#
# [4343 rows x 4 columns]

# %%
rfm_df = rfm[['Amount', 'Frequency', 'Recency']]

# Instantiate
scaler = StandardScaler()

# fit_transform
rfm_df_scaled = scaler.fit_transform(rfm_df)
rfm_df_scaled.shape
# Out:
# (4343, 3)

# %%
rfm_df_scaled
# Out:
# array([[-0.26967947, -0.73877865,  2.31427192],
#        [ 0.42844108,  0.95342687, -0.89858992],
#        [ 0.02143194, -0.46614554, -0.17470438],
#        ...,
#        [-0.24107435, -0.63536609, -0.83909248],
#        [ 0.06964275,  6.34968227, -0.87875744],
#        [ 0.0279175 , -0.09950101, -0.49202407]])

# %%
rfm_df_scaled = pd.DataFrame(rfm_df_scaled)
rfm_df_scaled.columns = ['Amount', 'Frequency', 'Recency']
rfm_df_scaled
# Out:
#         Amount  Frequency   Recency
# 0    -0.269679  -0.738779  2.314272
# 1     0.428441   0.953427 -0.898590
# 2     0.021432  -0.466146 -0.174704
# 3     0.015003  -0.071298 -0.730014
# 4    -0.215514  -0.597762  2.155612
# ...        ...        ...       ...
# 4338 -0.240426  -0.663570  1.838292
# 4339 -0.256588  -0.691773  0.876417
# 4340 -0.241074  -0.635366 -0.839092
# 4341  0.069643   6.349682 -0.878757
# 4342  0.027917  -0.099501 -0.492024
#
# [4343 rows x 3 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


# Apply K-means clustering
kmeans = KMeans(n_clusters=4, max_iter=50)
kmeans.fit(rfm_df_scaled)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(max_iter=50, n_clusters=4)

# %%
kmeans.labels_
# Out:
# array([1, 0, 0, ..., 0, 3, 0], dtype=int32)

# %%
set(kmeans.labels_)
# Out:
# {0, 1, 2, 3}

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Assuming rfm_df_scaled is your scaled dataset
# Calculate WCSS for different values of K
wcss = []
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50, n_init=10, random_state=0)
    kmeans.fit(rfm_df_scaled)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Curve
plt.plot(range_n_clusters, wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Apply K-means clustering
kmeans = KMeans(n_clusters=3, max_iter=300)
kmeans.fit(rfm_df_scaled)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
import pickle
# Serialize the model using pickle

filename = 'kmeans_model.pkl'

with open('kmeans_model_saved.pkl', 'wb') as file:
    pickle.dump(kmeans, file)
    
file.close()
pickle.dump(kmeans, open('kmeans_model.pkl','wb'))
print("K-means model saved successfully.")
# Out:
# K-means model saved successfully.

# %%
kmeans.labels_
# Out:
# array([1, 0, 0, ..., 0, 2, 0], dtype=int32)
